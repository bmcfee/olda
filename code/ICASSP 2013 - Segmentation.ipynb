# %%
import mir_eval
import sys
import os
import glob
import numpy as np
from pprint import pprint

# %%
ROOTPATH = '/home/bmcfee/git/olda/data/'

# %%
def load_annotations(path):
    
    files = sorted(glob.glob(path))
    
    data = [mir_eval.util.import_segment_boundaries(f) for f in files]
    
    return data

# %%
def evaluate_set(SETNAME, agg=True):
    
    truth = load_annotations('%s/truth/%s/*' % (ROOTPATH, SETNAME))
    
    algos = map(os.path.basename, sorted(glob.glob('%s/predictions/%s/*' % (ROOTPATH, SETNAME))))
    
    scores = {}
    for A in algos:
        print 'Scoring %s...' % A
        # Load the corresponding predictions
        predictions = load_annotations('%s/predictions/%s/%s/*' % (ROOTPATH, SETNAME, A))
        
        # Scrub the predictions to valid ranges
        for i in range(len(predictions)):
            predictions[i] = mir_eval.util.adjust_segment_boundaries(predictions[i], t_max=truth[i][-1])
            
        # Compute metrics
        my_scores = []
        
        for t, p in zip(truth, predictions):
            S = []
            S.extend(mir_eval.segment.boundary_detection(t, p, window=0.5))
            S.extend(mir_eval.segment.boundary_detection(t, p, window=3.0))
            S.extend(mir_eval.segment.boundary_deviation(t, p))
            S.extend(mir_eval.segment.frame_clustering_nce(t, p))
            S.extend(mir_eval.segment.frame_clustering_pairwise(t, p))
            S.extend(mir_eval.segment.frame_clustering_mutual_information(t, p))
            S.append(mir_eval.segment.frame_clustering_rand(t, p))
            my_scores.append(S)
            
        my_scores = np.array(my_scores)
        if agg:
            scores[A] = np.mean(my_scores, axis=0)
        else:
            scores[A] = my_scores
        
    return scores

# %%
METRICS = ['BD.5 P', 'BD.5 R', 'BD.5 F', 
           'BD3 P', 'BD3 R', 'BD3 F', 
           'BDev T2P', 'BDev P2T', 
           'S_O', 'S_U', 'S_F', 
           'Pair_P', 'Pair_R', 'Pair_F', 
           'MI', 'AMI', 'NMI', 'ARI']

# %%
def save_results(outfile, predictions):
    
    with open(outfile, 'w') as f:
        f.write('%s,%s\n' % ('Algorithm', ','.join(METRICS)))
        
        for k in predictions:
            f.write('%s,%s\n' % (k, ','.join(map(lambda x: '%.8f' % x, predictions[k]))))

# %%
def plot_score_histograms(data):
    
    figure(figsize=(16,10))
    for i in range(len(METRICS)):
        subplot(6,3, i+1)
        hist(data[:, i], normed=True)
        xlim([0.0, max(1.0, np.max(data[:, i]))])
        legend([METRICS[i]])

# %%
def plot_boxes(data):
    figure(figsize=(10,8))
    for i in range(len(METRICS)):
        subplot(6, 3, i+1)
        my_data = []
        leg = []
        for k in data:
            leg.append(k)
            my_data.append(data[k][:, i])
        my_data = np.array(my_data).T
        boxplot(my_data)
        xticks(range(1, 1+len(data)), leg)
        ylim([0, max(1.0, my_data.max())])
        tight_layout()
        title(METRICS[i])

# %%
def get_worst_examples(SETNAME, perfs, algorithm, idx, k=10):
    files = sorted(map(os.path.basename, glob.glob('%s/predictions/%s/%s/*' % (ROOTPATH, SETNAME, algorithm))))
    
    
    indices = np.argsort(perfs[algorithm][:, idx])[:k]
    
    print '%s\t%s\t%s' % (METRICS[idx], SETNAME, algorithm)
    for v in indices:
        print '%.3f\t%s' % (perfs[algorithm][v, idx], files[v])

# %%
for alg in sorted(ind_perfs_beatles.keys()):
    get_worst_examples('BEATLES', ind_perfs_beatles, alg, 8, 5)
    print
# Out:
# S_O	BEATLES	smga1
# 0.420	09_-_You_Never_Give_Me_Your_Money.lab
# 0.548	06_-_I_Want_You.lab
# 0.570	10_-_Baby_It's_You.lab
# 0.572	16_-_The_End.lab
# 0.577	11_-_Mean_Mr_Mustard.lab
#
# S_O	BEATLES	smga2
# 0.412	09_-_You_Never_Give_Me_Your_Money.lab
# 0.540	06_-_I_Want_You.lab
# 0.570	CD1_-_08_-_Happiness_is_a_Warm_Gun.lab
# 0.585	16_-_The_End.lab
# 0.615	CD1_-_02_-_Dear_Prudence.lab
#
# S_O	BEATLES	sup
# 0.219	17_-_Her_Majesty.lab
# 0.396	11_-_Mean_Mr_Mustard.lab
# 0.410	09_-_You_Never_Give_Me_Your_Money.lab
# 0.508	14_-_Golden_Slumbers.lab
# 0.519	05_-_Dig_It.lab
#
# S_O	BEATLES	traintrain
# 0.225	17_-_Her_Majesty.lab
# 0.396	11_-_Mean_Mr_Mustard.lab
# 0.451	09_-_You_Never_Give_Me_Your_Money.lab
# 0.491	05_-_Dig_It.lab
# 0.544	12_-_Sgt._Pepper's_Lonely_Hearts_Club_Band_(Reprise).lab
#
# S_O	BEATLES	unsup
# 0.379	17_-_Her_Majesty.lab
# 0.386	11_-_Mean_Mr_Mustard.lab
# 0.477	09_-_You_Never_Give_Me_Your_Money.lab
# 0.542	05_-_Dig_It.lab
# 0.555	16_-_The_End.lab

# %%
perfs_beatles = evaluate_set('BEATLES')
# Out:
# Scoring smga1...
# Scoring smga2...
# Scoring sup...
# Scoring traintrain...
# Scoring unsup...

# %%
ind_perfs_beatles = evaluate_set('BEATLES', agg=False)
# Out:
# Scoring smga1...
# Scoring smga2...
# Scoring sup...
# Scoring traintrain...
# Scoring unsup...

# %%
plot_boxes(ind_perfs_beatles)

# %%
save_results('/home/bmcfee/git/olda/data/beatles_scores.csv', perfs_beatles)

# %%
pprint(perfs_beatles)
# Out:
# {'smga1': array([ 0.35848177,  0.39340451,  0.36953244,  0.76901394,  0.80811573,
#         0.78046769,  1.15248184,  1.62451732,  0.81082868,  0.85842994,
#         0.82897101,  0.70173186,  0.79827864,  0.72933496,  1.75718127,
#         0.76488214,  0.81191025,  0.68312399]),
#  'smga2': array([ 0.3338195 ,  0.3671374 ,  0.34389022,  0.74448069,  0.74567912,
#         0.7362441 ,  1.43455084,  1.65903464,  0.80738387,  0.83273754,
#         0.81257208,  0.69613841,  0.75846218,  0.7052857 ,  1.70208372,
#         0.74671145,  0.79177247,  0.65213521]),
#  'sup': array([ 0.41815543,  0.45062453,  0.42395317,  0.67195632,  0.69354366,
#         0.66978051,  1.48671788,  1.81111453,  0.81512523,  0.81867667,
#         0.80980674,  0.72137651,  0.70012259,  0.68905294,  1.65323131,
#         0.74185534,  0.79423665,  0.63590818]),
#  'traintrain': array([ 0.4406446 ,  0.4670756 ,  0.44402774,  0.68804255,  0.70088535,
#         0.68277064,  1.36197765,  1.69209777,  0.81928647,  0.82700835,
#         0.8165886 ,  0.7260742 ,  0.71767592,  0.70204817,  1.67290143,
#         0.75224052,  0.8022258 ,  0.65126531]),
#  'unsup': array([ 0.40607656,  0.40589373,  0.39813159,  0.67502165,  0.64396368,
#         0.65052912,  1.84207821,  1.96449441,  0.81909338,  0.79375813,
#         0.80057977,  0.73495601,  0.66514541,  0.68080517,  1.59877524,
#         0.73179906,  0.78298771,  0.62289594])}

# %%
perfs_salami = evaluate_set('SALAMI', agg=True)
# Out:
# Scoring smga1...
# Scoring smga2...
# Scoring sup...
# Scoring traintrain...
# Scoring unsup...

# %%
ind_perfs_salami = evaluate_set('SALAMI', agg=False)
# Out:
# Scoring smga1...
# Scoring smga2...
# Scoring sup...
# Scoring traintrain...
# Scoring unsup...

# %%
plot_boxes(ind_perfs_salami)

# %%
pprint(perfs_salami)
# Out:
# {'smga1': array([ 0.20908939,  0.359883  ,  0.25621431,  0.51158944,  0.73293165,
#         0.58900087,  1.44395607,  5.21269008,  0.71435089,  0.89521267,
#         0.78623916,  0.4482276 ,  0.82188953,  0.55046362,  2.02822911,
#         0.68987443,  0.78058019,  0.50768952]),
#  'smga2': array([ 0.20173772,  0.35659802,  0.24860064,  0.50789503,  0.696236  ,
#         0.57274115,  1.60723343,  5.2244346 ,  0.71911437,  0.88584384,
#         0.78604995,  0.45637552,  0.80160866,  0.54919438,  2.00451576,
#         0.68786749,  0.77667224,  0.50359401]),
#  'sup': array([ 0.40295337,  0.40797056,  0.3952452 ,  0.60874126,  0.61411047,
#         0.59731782,  2.1183833 ,  2.95477768,  0.80266187,  0.83164249,
#         0.80833587,  0.63829227,  0.710029  ,  0.64038911,  1.85841929,
#         0.74415983,  0.79818059,  0.59240964]),
#  'traintrain': array([ 0.40877996,  0.4093597 ,  0.3985401 ,  0.62680805,  0.62418272,
#         0.61092244,  2.02486389,  2.73375604,  0.8101982 ,  0.82910166,
#         0.81095699,  0.65235766,  0.70335502,  0.64473306,  1.85047192,
#         0.74521717,  0.80008992,  0.59646498]),
#  'unsup': array([ 0.39041098,  0.36960946,  0.37047033,  0.60535709,  0.57005402,
#         0.57430236,  2.84265736,  2.98099893,  0.80790124,  0.80598502,
#         0.79870665,  0.65645807,  0.66748948,  0.63169105,  1.79161617,
#         0.7325436 ,  0.7868232 ,  0.57975581])}

# %%
save_results('/home/bmcfee/git/olda/data/salami_scores.csv', perfs_salami)
