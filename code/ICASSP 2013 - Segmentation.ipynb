# %%
import mir_eval
import sys
import os
import glob
import numpy as np
from pprint import pprint
import scipy.stats

# %%
ROOTPATH = '/home/bmcfee/git/olda/data/'

# %%
def load_annotations(path):
    
    files = sorted(glob.glob(path))
    
    data = [mir_eval.util.import_segment_boundaries(f) for f in files]
    
    return data

# %%
def evaluate_set(SETNAME, agg=True):
    
    truth = load_annotations('%s/truth/%s/*' % (ROOTPATH, SETNAME))
    
    algos = map(os.path.basename, sorted(glob.glob('%s/predictions/%s/*' % (ROOTPATH, SETNAME))))
    
    scores = {}
    for A in algos:
        print 'Scoring %s...' % A
        # Load the corresponding predictions
        predictions = load_annotations('%s/predictions/%s/%s/*' % (ROOTPATH, SETNAME, A))
        
        # Scrub the predictions to valid ranges
        for i in range(len(predictions)):
            predictions[i] = mir_eval.util.adjust_segment_boundaries(predictions[i], t_max=truth[i][-1])
            
        # Compute metrics
        my_scores = []
        
        for t, p in zip(truth, predictions):
            S = []
            S.extend(mir_eval.segment.boundary_detection(t, p, window=0.5))
            S.extend(mir_eval.segment.boundary_detection(t, p, window=3.0))
            S.extend(mir_eval.segment.boundary_deviation(t, p))
            S.extend(mir_eval.segment.frame_clustering_nce(t, p))
            S.extend(mir_eval.segment.frame_clustering_pairwise(t, p))
            S.extend(mir_eval.segment.frame_clustering_mutual_information(t, p))
            S.append(mir_eval.segment.frame_clustering_rand(t, p))
            my_scores.append(S)
            
        my_scores = np.array(my_scores)
        if agg:
            scores[A] = np.mean(my_scores, axis=0)
        else:
            scores[A] = my_scores
        
    return scores

# %%
METRICS = ['BD.5 P', 'BD.5 R', 'BD.5 F', 
           'BD3 P', 'BD3 R', 'BD3 F', 
           'BDev T2P', 'BDev P2T', 
           'S_O', 'S_U', 'S_F', 
           'Pair_P', 'Pair_R', 'Pair_F', 
           'MI', 'AMI', 'NMI', 'ARI']

# %%
def save_results(outfile, predictions):
    
    with open(outfile, 'w') as f:
        f.write('%s,%s\n' % ('Algorithm', ','.join(METRICS)))
        
        for k in predictions:
            f.write('%s,%s\n' % (k, ','.join(map(lambda x: '%.8f' % x, predictions[k]))))

# %%
def plot_score_histograms(data):
    
    figure(figsize=(16,10))
    for i in range(len(METRICS)):
        subplot(6,3, i+1)
        hist(data[:, i], normed=True)
        xlim([0.0, max(1.0, np.max(data[:, i]))])
        legend([METRICS[i]])

# %%
def plot_boxes(data):
    figure(figsize=(10,8))
    for i in range(len(METRICS)):
        subplot(6, 3, i+1)
        my_data = []
        leg = []
        for k in data:
            leg.append(k)
            my_data.append(data[k][:, i])
        my_data = np.array(my_data).T
        boxplot(my_data)
        xticks(range(1, 1+len(data)), leg)
        ylim([0, max(1.0, my_data.max())])
        tight_layout()
        title(METRICS[i])

# %%
def get_top_sig(SETNAME, perfs, idx, p=0.05):
    
    # Pluck out the relevant algorithm
    data = {}
    mean = {}
    best_mean = -np.inf
    best_alg  = None
    n_algs    = len(perfs)
    
    for k in perfs:
        data[k] = perfs[k][:, idx]
        mean[k] = np.mean(data[k])
        if mean[k] > best_mean:
            best_mean = mean[k]
            best_alg = k
    
    
    
    # Compute pairwise tests against the best
    sigdiff = {}
    for k in perfs:
        if k == best_alg:
            sigdiff[k] = 1.0
            continue
        # Get the p-value
        _z, _p = scipy.stats.wilcoxon(data[best_alg], data[k])
        sigdiff[k] = _p
        
        
    # Print the results
    ordering = [(v, k) for k, v in mean.iteritems()]
    ordering.sort(reverse=True)
    
    print '%s\t%s' % (METRICS[idx], SETNAME)
    
    for (v, k) in ordering:
        print '%.3f\t%10s\t%.3e\t%r' % (v, k, sigdiff[k], sigdiff[k] * (n_algs -1) < p)

# %%
def get_worst_examples(SETNAME, perfs, algorithm, idx, k=10):
    files = sorted(map(os.path.basename, glob.glob('%s/predictions/%s/%s/*' % (ROOTPATH, SETNAME, algorithm))))
    
    
    indices = np.argsort(perfs[algorithm][:, idx])[:k]
    
    print '%s\t%s\t%s' % (METRICS[idx], SETNAME, algorithm)
    for v in indices:
        print '%.3f\t%s' % (perfs[algorithm][v, idx], files[v])

# %%
for alg in sorted(ind_perfs_beatles.keys()):
    get_worst_examples('BEATLES', ind_perfs_beatles, alg, 10, 10)
    print
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-25-a28b1869ea60> in <module>()
#       1 for alg in sorted(ind_perfs_beatles.keys()):
# ----> 2     get_worst_examples('BEATLES', ind_perfs_beatles, alg, 10, 10)
#       3     print
#
# <ipython-input-10-54e4ccdea41c> in get_worst_examples(SETNAME, perfs, algorithm, idx, k)
#       3
#       4
# ----> 5     indices = np.argsort(perfs[algorithm][:, idx])[:k]
#       6
#       7     print '%s\t%s\t%s' % (METRICS[idx], SETNAME, algorithm)
#
# IndexError: too many indices

# %%
perfs_beatles = evaluate_set('BEATLES')
# Out:
# Scoring fda...
# Scoring olda...
# Scoring smga1...
# Scoring unsup...

# %%
pprint(perfs_beatles)
# Out:
# {'fda': array([ 0.34924383,  0.25253868,  0.27886357,  0.60320866,  0.41492809,
#         0.47244593,  5.98070391,  2.88706983,  0.87113962,  0.66688226,
#         0.74238466,  0.83043034,  0.49564252,  0.5882048 ,  1.3064908 ,
#         0.61275622,  0.72120783,  0.4958729 ]),
#  'olda': array([ 0.33112396,  0.30725837,  0.30799782,  0.59269939,  0.5188283 ,
#         0.53746101,  3.28296369,  2.82626257,  0.84393033,  0.77676447,
#         0.80237627,  0.77153295,  0.6358664 ,  0.67424651,  1.55824345,
#         0.71757199,  0.78319496,  0.61253364]),
#  'rfda': array([ 0.33624223,  0.29061494,  0.30072418,  0.60215461,  0.49394298,
#         0.52687901,  3.72743855,  2.87056425,  0.85311576,  0.75446407,
#         0.79354579,  0.79241001,  0.60266909,  0.66063685,  1.50671706,
#         0.70106415,  0.77435655,  0.59470454]),
#  'smga1': array([ 0.14716361,  0.17188831,  0.15561933,  0.62729373,  0.72829904,
#         0.66129793,  1.86143128,  3.12297011,  0.81082868,  0.85842994,
#         0.82897101,  0.70173186,  0.79827864,  0.72933496,  1.75718127,
#         0.76488214,  0.81191025,  0.68312399]),
#  'unsup': array([ 0.29109819,  0.22326441,  0.2451974 ,  0.58471022,  0.44131454,
#         0.49088096,  4.51131844,  3.10907821,  0.84883967,  0.74114044,
#         0.7849597 ,  0.79152422,  0.5958849 ,  0.65969047,  1.47986336,
#         0.69283429,  0.76616975,  0.59215214])}

# %%
save_results('/home/bmcfee/git/olda/data/beatles_scores_fixed_rfda.csv', perfs_beatles)

# %%
ind_perfs_beatles = evaluate_set('BEATLES', agg=False)
# Out:
# Scoring fda...
# Scoring olda...
# Scoring rfda...
# Scoring smga1...
# Scoring unsup...

# %%
perfs_beatles = {}
for alg in perfs_beatles:
    perfs_beatles[alg] = np.mean(perfs_beatles[alg], axis=0)

# %%
for idx in range(len(METRICS)):
    get_top_sig('BEATLES', ind_perfs_beatles, idx=idx)
    print
# Out:
# BD.5 P	BEATLES
# 0.349	       fda	1.000e+00	False
# 0.336	      rfda	2.640e-01	False
# 0.331	      olda	2.009e-01	False
# 0.291	     unsup	4.974e-06	True
# 0.147	     smga1	1.395e-21	True
#
# BD.5 R	BEATLES
# 0.307	      olda	1.000e+00	False
# 0.291	      rfda	1.705e-02	False
# 0.253	       fda	4.127e-09	True
# 0.223	     unsup	5.293e-12	True
# 0.172	     smga1	5.920e-11	True
#
# BD.5 F	BEATLES
# 0.308	      olda	1.000e+00	False
# 0.301	      rfda	4.331e-01	False
# 0.279	       fda	1.187e-03	True
# 0.245	     unsup	2.832e-08	True
# 0.156	     smga1	1.059e-15	True
#
# BD3 P	BEATLES
# 0.627	     smga1	1.000e+00	False
# 0.603	       fda	1.542e-01	False
# 0.602	      rfda	1.824e-01	False
# 0.593	      olda	3.217e-02	False
# 0.585	     unsup	1.804e-02	False
#
# BD3 R	BEATLES
# 0.728	     smga1	1.000e+00	False
# 0.519	      olda	1.400e-16	True
# 0.494	      rfda	1.612e-18	True
# 0.441	     unsup	4.151e-23	True
# 0.415	       fda	2.791e-23	True
#
# BD3 F	BEATLES
# 0.661	     smga1	1.000e+00	False
# 0.537	      olda	3.421e-10	True
# 0.527	      rfda	4.344e-11	True
# 0.491	     unsup	8.919e-15	True
# 0.472	       fda	2.072e-16	True
#
# BDev T2P	BEATLES
# 5.981	       fda	1.000e+00	False
# 4.511	     unsup	3.324e-07	True
# 3.727	      rfda	1.721e-17	True
# 3.283	      olda	1.360e-20	True
# 1.861	     smga1	1.159e-21	True
#
# BDev P2T	BEATLES
# 3.123	     smga1	1.000e+00	False
# 3.109	     unsup	6.081e-01	False
# 2.887	       fda	3.551e-01	False
# 2.871	      rfda	4.975e-01	False
# 2.826	      olda	3.741e-01	False
#
# S_O	BEATLES
# 0.871	       fda	1.000e+00	False
# 0.853	      rfda	1.352e-11	True
# 0.849	     unsup	1.257e-08	True
# 0.844	      olda	6.060e-18	True
# 0.811	     smga1	9.329e-19	True
#
# S_U	BEATLES
# 0.858	     smga1	1.000e+00	False
# 0.777	      olda	2.615e-17	True
# 0.754	      rfda	1.510e-20	True
# 0.741	     unsup	1.750e-25	True
# 0.667	       fda	4.300e-26	True
#
# S_F	BEATLES
# 0.829	     smga1	1.000e+00	False
# 0.802	      olda	2.273e-06	True
# 0.794	      rfda	2.421e-08	True
# 0.785	     unsup	1.634e-11	True
# 0.742	       fda	4.025e-17	True
#
# Pair_P	BEATLES
# 0.830	       fda	1.000e+00	False
# 0.792	      rfda	2.875e-16	True
# 0.792	     unsup	8.075e-09	True
# 0.772	      olda	6.320e-25	True
# 0.702	     smga1	1.530e-21	True
#
# Pair_R	BEATLES
# 0.798	     smga1	1.000e+00	False
# 0.636	      olda	9.264e-21	True
# 0.603	      rfda	1.671e-23	True
# 0.596	     unsup	4.643e-26	True
# 0.496	       fda	7.176e-28	True
#
# Pair_F	BEATLES
# 0.729	     smga1	1.000e+00	False
# 0.674	      olda	2.193e-06	True
# 0.661	      rfda	4.444e-08	True
# 0.660	     unsup	2.051e-08	True
# 0.588	       fda	8.141e-16	True
#
# MI	BEATLES
# 1.757	     smga1	1.000e+00	False
# 1.558	      olda	8.634e-19	True
# 1.507	      rfda	9.144e-22	True
# 1.480	     unsup	3.862e-26	True
# 1.306	       fda	1.194e-26	True
#
# AMI	BEATLES
# 0.765	     smga1	1.000e+00	False
# 0.718	      olda	2.455e-07	True
# 0.701	      rfda	1.828e-09	True
# 0.693	     unsup	8.881e-11	True
# 0.613	       fda	4.376e-18	True
#
# NMI	BEATLES
# 0.812	     smga1	1.000e+00	False
# 0.783	      olda	1.191e-06	True
# 0.774	      rfda	7.708e-09	True
# 0.766	     unsup	1.189e-11	True
# 0.721	       fda	2.583e-17	True
#
# ARI	BEATLES
# 0.683	     smga1	1.000e+00	False
# 0.613	      olda	4.093e-07	True
# 0.595	      rfda	9.142e-09	True
# 0.592	     unsup	1.980e-09	True
# 0.496	       fda	2.428e-17	True

# %%
plot_boxes(ind_perfs_beatles)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-4d3e60ab95e8> in <module>()
# ----> 1 plot_boxes(ind_perfs_beatles)
#
# <ipython-input-8-9b37f413770b> in plot_boxes(data)
#       7         for k in data:
#       8             leg.append(k)
# ----> 9             my_data.append(data[k][:, i])
#      10         my_data = np.array(my_data).T
#      11         boxplot(my_data)
#
# IndexError: too many indices

# %%
perfs_salami = evaluate_set('SALAMI', agg=True)
# Out:
# Scoring CNMF...
# Scoring SIPLCA...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-94ab73d7fd62> in <module>()
# ----> 1 perfs_salami = evaluate_set('SALAMI', agg=True)
#
# <ipython-input-4-746dd2359713> in evaluate_set(SETNAME, agg)
#      24             S.extend(mir_eval.segment.boundary_deviation(t, p))
#      25             S.extend(mir_eval.segment.frame_clustering_nce(t, p))
# ---> 26             S.extend(mir_eval.segment.frame_clustering_pairwise(t, p))
#      27             S.extend(mir_eval.segment.frame_clustering_mutual_information(t, p))
#      28             S.append(mir_eval.segment.frame_clustering_rand(t, p))
#
# /home/bmcfee/lib/python/mir_eval/segment.pyc in frame_clustering_pairwise(annotated_boundaries, predicted_boundaries, frame_size, beta)
#     173     # Construct the label-agreement matrices
#     174     A1 = np.triu(np.equal.outer(y_true, y_true))
# --> 175     A2 = np.triu(np.equal.outer(y_pred, y_pred))
#     176
#     177     matches = float((A1 & A2).sum())
#
# /usr/lib/python2.7/dist-packages/numpy/lib/twodim_base.pyc in triu(m, k)
#     447     """
#     448     m = asanyarray(m)
# --> 449     out = multiply((1 - tri(m.shape[0], m.shape[1], k - 1, dtype=m.dtype)), m)
#     450     return out
#     451
#
# KeyboardInterrupt:

# %%
ind_perfs_salami = evaluate_set('SALAMI', agg=False)
# Out:
# Scoring CNMF...
# Scoring SIPLCA...
# Scoring fda...
# Scoring olda...
# Scoring rfda...
# Scoring smga1...
# Scoring unsup...

# %%
perfs_salami = {}
for alg in perfs_salami:
    perfs_salami[alg] = np.mean(perfs_salami[alg], axis=0)

# %%
pprint(perfs_salami)
# Out:
# {'CNMF': array([ 0.10514414,  0.13322015,  0.10971976,  0.45024537,  0.54333524,
#         0.46309017,  4.1670073 ,  5.94623858,  0.76659964,  0.7972802 ,
#         0.76675763,  0.57638598,  0.63895335,  0.55031555,  1.77360763,
#         0.66952316,  0.74624826,  0.49008302]),
#  'SIPLCA': array([  0.2100008 ,   0.10169394,   0.12774307,   0.45112871,
#          0.22782295,   0.28610934,  16.93411006,   5.80685512,
#          0.8733449 ,   0.53755385,   0.64316976,   0.8135197 ,
#          0.36192509,   0.45888541,   1.1118125 ,   0.4785737 ,
#          0.6205327 ,   0.34372012]),
#  'fda': array([ 0.24247435,  0.21541462,  0.220376  ,  0.50923305,  0.46011133,
#         0.46620806,  5.28937208,  5.36113716,  0.80499737,  0.82164462,
#         0.80434166,  0.64444017,  0.69293478,  0.63421711,  1.83293102,
#         0.73593686,  0.79297039,  0.58378044]),
#  'olda': array([ 0.26876813,  0.23805328,  0.24459563,  0.5071441 ,  0.46166062,
#         0.46707579,  4.88364086,  5.46310697,  0.80523509,  0.82667014,
#         0.8070031 ,  0.64243253,  0.70003254,  0.63711478,  1.84605023,
#         0.74070429,  0.79645949,  0.58776771]),
#  'rfda': array([ 0.26561919,  0.24693863,  0.24811171,  0.50830086,  0.48249821,
#         0.47866033,  4.42014912,  5.13304743,  0.80079217,  0.83792081,
#         0.81037963,  0.63059179,  0.71903335,  0.64025885,  1.87468287,
#         0.7464125 ,  0.80051036,  0.5926424 ]),
#  'smga1': array([ 0.11493075,  0.17796945,  0.13437579,  0.43375133,  0.6661867 ,
#         0.5076943 ,  2.09821367,  7.15111203,  0.71435089,  0.89521267,
#         0.78623916,  0.4482276 ,  0.82188953,  0.55046362,  2.02822911,
#         0.68987443,  0.78058019,  0.50768952]),
#  'unsup': array([ 0.24329676,  0.18876667,  0.20551627,  0.50307164,  0.39313594,
#         0.42644553,  6.83715821,  5.67834271,  0.81325588,  0.78945227,
#         0.79156823,  0.66952551,  0.64259163,  0.62045937,  1.75142261,
#         0.71735653,  0.77948941,  0.56500716])}

# %%
save_results('/home/bmcfee/git/olda/data/salami_scores_fixed_rfda.csv', perfs_salami)

# %%
for alg in sorted(ind_perfs_salami.keys()):
    get_worst_examples('SALAMI', ind_perfs_salami, alg, 8, 5)
    print
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-30004fe421d5> in <module>()
#       1 for alg in sorted(ind_perfs_salami.keys()):
# ----> 2     get_worst_examples('SALAMI', ind_perfs_salami, alg, 8, 5)
#       3     print
#
# <ipython-input-10-54e4ccdea41c> in get_worst_examples(SETNAME, perfs, algorithm, idx, k)
#       3
#       4
# ----> 5     indices = np.argsort(perfs[algorithm][:, idx])[:k]
#       6
#       7     print '%s\t%s\t%s' % (METRICS[idx], SETNAME, algorithm)
#
# IndexError: too many indices

# %%
for idx in range(len(METRICS)):
    get_top_sig('SALAMI', ind_perfs_salami, idx=idx)
    print
# Out:
# BD.5 P	SALAMI
# 0.269	      olda	1.000e+00	False
# 0.266	      rfda	4.492e-01	False
# 0.243	     unsup	8.014e-04	True
# 0.242	       fda	9.278e-05	True
# 0.210	    SIPLCA	1.556e-05	True
# 0.115	     smga1	2.847e-34	True
# 0.105	      CNMF	6.669e-32	True
#
# BD.5 R	SALAMI
# 0.247	      rfda	1.000e+00	False
# 0.238	      olda	1.896e-02	False
# 0.215	       fda	1.110e-06	True
# 0.189	     unsup	7.651e-15	True
# 0.178	     smga1	1.202e-10	True
# 0.133	      CNMF	1.427e-18	True
# 0.102	    SIPLCA	2.594e-27	True
#
# BD.5 F	SALAMI
# 0.248	      rfda	1.000e+00	False
# 0.245	      olda	8.228e-01	False
# 0.220	       fda	4.063e-05	True
# 0.206	     unsup	6.036e-08	True
# 0.134	     smga1	9.551e-26	True
# 0.128	    SIPLCA	2.909e-22	True
# 0.110	      CNMF	1.674e-28	True
#
# BD3 P	SALAMI
# 0.509	       fda	1.000e+00	False
# 0.508	      rfda	8.418e-01	False
# 0.507	      olda	9.974e-01	False
# 0.503	     unsup	2.259e-01	False
# 0.451	    SIPLCA	7.472e-05	True
# 0.450	      CNMF	6.679e-06	True
# 0.434	     smga1	3.977e-11	True
#
# BD3 R	SALAMI
# 0.666	     smga1	1.000e+00	False
# 0.543	      CNMF	1.977e-14	True
# 0.482	      rfda	4.393e-25	True
# 0.462	      olda	3.841e-28	True
# 0.460	       fda	1.272e-27	True
# 0.393	     unsup	1.142e-37	True
# 0.228	    SIPLCA	6.485e-42	True
#
# BD3 F	SALAMI
# 0.508	     smga1	1.000e+00	False
# 0.479	      rfda	6.016e-03	True
# 0.467	      olda	4.497e-04	True
# 0.466	       fda	2.222e-04	True
# 0.463	      CNMF	4.183e-05	True
# 0.426	     unsup	1.947e-12	True
# 0.286	    SIPLCA	5.717e-34	True
#
# BDev T2P	SALAMI
# 16.934	    SIPLCA	1.000e+00	False
# 6.837	     unsup	4.313e-34	True
# 5.289	       fda	1.468e-38	True
# 4.884	      olda	9.315e-40	True
# 4.420	      rfda	6.280e-41	True
# 4.167	      CNMF	3.119e-41	True
# 2.098	     smga1	3.570e-43	True
#
# BDev P2T	SALAMI
# 7.151	     smga1	1.000e+00	False
# 5.946	      CNMF	4.591e-03	True
# 5.807	    SIPLCA	5.163e-04	True
# 5.678	     unsup	3.126e-10	True
# 5.463	      olda	8.664e-12	True
# 5.361	       fda	1.675e-11	True
# 5.133	      rfda	1.370e-17	True
#
# S_O	SALAMI
# 0.873	    SIPLCA	1.000e+00	False
# 0.813	     unsup	1.711e-25	True
# 0.805	      olda	1.856e-29	True
# 0.805	       fda	5.568e-31	True
# 0.801	      rfda	5.636e-32	True
# 0.767	      CNMF	2.641e-37	True
# 0.714	     smga1	3.834e-43	True
#
# S_U	SALAMI
# 0.895	     smga1	1.000e+00	False
# 0.838	      rfda	1.255e-31	True
# 0.827	      olda	2.181e-35	True
# 0.822	       fda	1.495e-35	True
# 0.797	      CNMF	1.069e-37	True
# 0.789	     unsup	7.316e-42	True
# 0.538	    SIPLCA	4.407e-43	True
#
# S_F	SALAMI
# 0.810	      rfda	1.000e+00	False
# 0.807	      olda	2.379e-02	False
# 0.804	       fda	1.224e-03	True
# 0.792	     unsup	6.695e-17	True
# 0.786	     smga1	4.403e-14	True
# 0.767	      CNMF	3.378e-24	True
# 0.643	    SIPLCA	2.833e-36	True
#
# Pair_P	SALAMI
# 0.814	    SIPLCA	1.000e+00	False
# 0.670	     unsup	4.557e-31	True
# 0.644	       fda	4.148e-36	True
# 0.642	      olda	6.822e-36	True
# 0.631	      rfda	1.091e-37	True
# 0.576	      CNMF	1.053e-36	True
# 0.448	     smga1	2.987e-43	True
#
# Pair_R	SALAMI
# 0.822	     smga1	1.000e+00	False
# 0.719	      rfda	3.269e-29	True
# 0.700	      olda	2.338e-33	True
# 0.693	       fda	3.835e-32	True
# 0.643	     unsup	5.929e-40	True
# 0.639	      CNMF	1.191e-35	True
# 0.362	    SIPLCA	5.271e-43	True
#
# Pair_F	SALAMI
# 0.640	      rfda	1.000e+00	False
# 0.637	      olda	4.071e-01	False
# 0.634	       fda	1.428e-01	False
# 0.620	     unsup	2.068e-05	True
# 0.550	     smga1	2.061e-26	True
# 0.550	      CNMF	4.297e-21	True
# 0.459	    SIPLCA	5.693e-27	True
#
# MI	SALAMI
# 2.028	     smga1	1.000e+00	False
# 1.875	      rfda	2.367e-32	True
# 1.846	      olda	5.677e-36	True
# 1.833	       fda	8.286e-36	True
# 1.774	      CNMF	9.552e-38	True
# 1.751	     unsup	5.515e-42	True
# 1.112	    SIPLCA	3.059e-43	True
#
# AMI	SALAMI
# 0.746	      rfda	1.000e+00	False
# 0.741	      olda	8.257e-03	True
# 0.736	       fda	3.815e-05	True
# 0.717	     unsup	5.088e-16	True
# 0.690	     smga1	1.335e-21	True
# 0.670	      CNMF	7.702e-26	True
# 0.479	    SIPLCA	7.314e-39	True
#
# NMI	SALAMI
# 0.801	      rfda	1.000e+00	False
# 0.796	      olda	1.453e-02	False
# 0.793	       fda	1.911e-04	True
# 0.781	     smga1	5.444e-10	True
# 0.779	     unsup	2.399e-18	True
# 0.746	      CNMF	5.043e-30	True
# 0.621	    SIPLCA	1.212e-40	True
#
# ARI	SALAMI
# 0.593	      rfda	1.000e+00	False
# 0.588	      olda	1.935e-01	False
# 0.584	       fda	4.775e-02	False
# 0.565	     unsup	1.033e-07	True
# 0.508	     smga1	1.548e-23	True
# 0.490	      CNMF	9.894e-23	True
# 0.344	    SIPLCA	1.949e-32	True

# %%
plot_boxes(ind_perfs_salami)

# %% [markdown]
# # Figures

# %%
import librosa
import scipy.signal
import functools

# %%
def get_beat_mfccs(filename):
    y, sr = librosa.load(filename)
    
    S = librosa.feature.melspectrogram(y, sr, n_fft=2048, hop_length=64, n_mels=128, fmax=8000)
    
    tempo, beats = librosa.beat.beat_track(y, sr, n_fft=2048, hop_length=64)
    
    M = librosa.feature.mfcc(librosa.logamplitude(S), d=32)
    M = librosa.feature.sync(M, beats)
    return M

# %%
def compress_data(X, k):
    sigma = np.cov(X)
    e_vals, e_vecs = scipy.linalg.eig(sigma)
        
    e_vals = np.maximum(0.0, np.real(e_vals))
    e_vecs = np.real(e_vecs)
        
    idx = np.argsort(e_vals)[::-1]
        
    e_vals = e_vals[idx]
    e_vecs = e_vecs[:, idx]
        
    # Truncate to k dimensions
    if k < len(e_vals):
        e_vals = e_vals[:k]
        e_vecs = e_vecs[:, :k]
        
    # Normalize by the leading singular value of X
    Z = np.sqrt(e_vals.max())
        
    if Z > 0:
        e_vecs = e_vecs / Z
        
    return e_vecs.T.dot(X)

# %%
def make_rep_feature_plot(M):
    
    myimshow = functools.partial(imshow, aspect='auto', interpolation='none', origin='lower', cmap='gray_r')
    
    R = librosa.segment.recurrence_matrix(M, k=2*np.sqrt(1./M.shape[1]), sym=False).astype(np.float)
    
    Rskew = librosa.segment.structure_feature(R, pad=True)
    Rskew = np.roll(Rskew, M.shape[1], axis=0)
    
    
    Rfilt = scipy.signal.medfilt2d(Rskew, kernel_size=(1, 7))
    #Rfilt = Rfilt[Rfilt.sum(axis=1) > 0, :]
    
    Rlatent = compress_data(Rfilt, 8)
    #Rlatent = compress_data(Rfilt, R.shape[0])
    
    figure(figsize=(6,6))
    subplot(221)
    myimshow(R), title('Self-similarity')
    xlabel('Beat'), ylabel('Beat')
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    yticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(222)
    myimshow(Rskew), title('Skewed self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(223)
    myimshow(Rfilt), title('Filtered self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(224)
    myimshow(Rlatent, origin='upper', cmap='PRGn_r'), title('Latent repetition')
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    xlabel('Beat'), ylabel('Factor')
    tight_layout()
    
    savefig('/home/bmcfee/git/olda/paper/figs/rep.pdf', format='pdf', pad_inches=0, transparent=True)
    #savefig('/home/bmcfee/git/olda/paper/figs/rep.svg', format='svg', pad_inches=0, transparent=True, dpi=200)

# %%
M = get_beat_mfccs('/home/bmcfee/data/CAL500/mp3/2pac-trapped.mp3')

# %%
make_rep_feature_plot(M[:,40:137])

# %%
model_fda = np.load('/home/bmcfee/git/olda/data/model_fda_beatles.npy')
model_olda  = np.load('/home/bmcfee/git/olda/data/model_olda_beatles.npy')
figure(figsize=(8,8))
subplot(211)
imshow(model_fda, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('Beatles: FDA')
yticks([])
#ylabel("More important $\\rightarrow$")
#xticks([0, 32, 44, 76, 108], ['MFCC', 'Chroma', 'Rep-M', 'Rep-C', 'Time'], rotation=-30, horizontalalignment='left')
xticks([])
#colorbar()

subplot(212)
imshow(model_olda, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('Beatles: OLDA')
#colorbar(orientation='horizontal')
#ylabel("More important $\\rightarrow$")
yticks([])
xticks([0, 32, 44, 76, 108], ['MFCC', '$\uparrow$\nChroma', 'R-MFCC', 'R-Chroma', 'Time'], horizontalalignment='left')

tight_layout()
#savefig('/home/bmcfee/git/olda/paper/figs/w.pdf', format='pdf', pad_inches=0, transparent=True)

# %%
model_fda_beatles = np.load('/home/bmcfee/git/olda/data/model_fda_beatles.npy')
model_fda_salami = np.load('/home/bmcfee/git/olda/data/model_fda_salami.npy')
model_olda_beatles  = np.load('/home/bmcfee/git/olda/data/model_olda_beatles.npy')
model_olda_salami = np.load('/home/bmcfee/git/olda/data/model_olda_salami.npy')

figure(figsize=(14,8))
subplot(221)
imshow(model_fda_beatles, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('FDA - Beatles')
yticks([])
xticks([])

subplot(222)
imshow(model_fda_salami, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('FDA - Salami')
yticks([])
xticks([])

subplot(223)
imshow(model_olda_beatles, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('OLDA - Beatles')
yticks([])
xticks([0, 32, 44, 76, 108], ['MFCC', '$\uparrow$\nChroma', 'R-MFCC', 'R-Chroma', 'Time'], horizontalalignment='left')

subplot(224)
imshow(model_olda_salami, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('OLDA - Salami')
yticks([])
xticks([])
xticks([0, 32, 44, 76, 108], ['MFCC', '$\uparrow$\nChroma', 'R-MFCC', 'R-Chroma', 'Time'], horizontalalignment='left')

tight_layout()
#savefig('/home/bmcfee/git/olda/paper/figs/fda-vs-olda.pdf', format='pdf', pad_inches=0, transparent=True)

# %% [markdown]
# SVD stuff

# %%
def rep_feature_svd(M):
    
    myimshow = functools.partial(imshow, aspect='auto', interpolation='none', origin='lower', cmap='gray_r')
    
    R = librosa.segment.recurrence_matrix(M, k=2*np.sqrt(1./M.shape[1]), sym=False).astype(np.float)
    
    Rskew = librosa.segment.structure_feature(R, pad=True)
    Rskew = np.roll(Rskew, M.shape[1], axis=0)
    
    
    Rfilt = scipy.signal.medfilt2d(Rskew, kernel_size=(1, 7))
    #Rfilt = Rfilt[Rfilt.sum(axis=1) > 0, :]
    
    Rlatent = compress_data(Rfilt, 8)
    #Rlatent = compress_data(Rfilt, R.shape[0])
    
    figure(figsize=(12,4))
    subplot(131)
    myimshow(R), title('Self-similarity')
    xlabel('Beat'), ylabel('Beat')
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    yticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(132)
    myimshow(Rskew), title('Skewed self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(133)
    myimshow(Rfilt), title('Filtered self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    tight_layout()
    
    # Do the SVD
    U, sigma, Vh = scipy.linalg.svd(Rfilt)
    
    D_little = 32
    
    figure(figsize=(12,4))
    subplot(131)
    myimshow(U[:,:D_little], cmap='PRGn'), title('U')
    xlabel('Factor'), ylabel('Lag')
    #yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    #xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(132)
    plot(sigma / sigma[0]), axis('tight'), title('Normalized spectrum $\sigma/\sigma_1$')
    vlines([D_little], 0, 1)
    
    subplot(133)
    myimshow(Vh[:D_little], cmap='PRGn'), title('V\'')
    xlabel('Beat'), ylabel('Factor')
    #yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    #xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    tight_layout()
    # Reconstruct
    S_hat = np.zeros(U.shape[1])
    S_hat[:D_little] = sigma[:D_little]
    
    R_reconst = U.dot(np.diag(S_hat))
    R_reconst = R_reconst[:, :Vh.shape[0]].dot(Vh)
    
    figure(figsize=(12,6))
    subplot(121)
    myimshow(Rfilt), title('Original')
    subplot(122)
    myimshow(R_reconst), title('Reconstruction (d=%2d)' % D_little)
    tight_layout()
    
    figure(figsize=(16,32))
    
    for i in range(D_little):
        subplot(1+np.ceil(np.sqrt(D_little)), np.floor(np.sqrt(D_little)), i+1)
        myimshow(np.outer(U[:,i], Vh[i])), title('$U_{%d} V^\mathsf{T}_{%d}$' % (i, i))
    
    tight_layout()

# %%
rep_feature_svd(M)#[:,40:137])
