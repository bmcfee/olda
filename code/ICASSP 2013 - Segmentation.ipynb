# %%
import mir_eval
import sys
import os
import glob
import numpy as np
from pprint import pprint
import scipy.stats

# %%
ROOTPATH = '/home/bmcfee/git/olda/data/'

# %%
def load_annotations(path):
    
    files = sorted(glob.glob(path))
    
    data = [mir_eval.util.import_segment_boundaries(f) for f in files]
    
    return data

# %%
def evaluate_set(SETNAME, agg=True):
    
    truth = load_annotations('%s/truth/%s/*' % (ROOTPATH, SETNAME))
    
    algos = map(os.path.basename, sorted(glob.glob('%s/predictions/%s/*' % (ROOTPATH, SETNAME))))
    
    scores = {}
    for A in algos:
        print 'Scoring %s...' % A
        # Load the corresponding predictions
        predictions = load_annotations('%s/predictions/%s/%s/*' % (ROOTPATH, SETNAME, A))
        
        # Scrub the predictions to valid ranges
        for i in range(len(predictions)):
            predictions[i] = mir_eval.util.adjust_segment_boundaries(predictions[i], t_max=truth[i][-1])
            
        # Compute metrics
        my_scores = []
        
        for t, p in zip(truth, predictions):
            S = []
            S.extend(mir_eval.segment.boundary_detection(t, p, window=0.5))
            S.extend(mir_eval.segment.boundary_detection(t, p, window=3.0))
            S.extend(mir_eval.segment.boundary_deviation(t, p))
            S.extend(mir_eval.segment.frame_clustering_nce(t, p))
            S.extend(mir_eval.segment.frame_clustering_pairwise(t, p))
            S.extend(mir_eval.segment.frame_clustering_mutual_information(t, p))
            S.append(mir_eval.segment.frame_clustering_rand(t, p))
            my_scores.append(S)
            
        my_scores = np.array(my_scores)
        if agg:
            scores[A] = np.mean(my_scores, axis=0)
        else:
            scores[A] = my_scores
        
    return scores

# %%
METRICS = ['BD.5 P', 'BD.5 R', 'BD.5 F', 
           'BD3 P', 'BD3 R', 'BD3 F', 
           'BDev T2P', 'BDev P2T', 
           'S_O', 'S_U', 'S_F', 
           'Pair_P', 'Pair_R', 'Pair_F', 
           'MI', 'AMI', 'NMI', 'ARI']

# %%
def save_results(outfile, predictions):
    
    with open(outfile, 'w') as f:
        f.write('%s,%s\n' % ('Algorithm', ','.join(METRICS)))
        
        for k in predictions:
            f.write('%s,%s\n' % (k, ','.join(map(lambda x: '%.8f' % x, predictions[k]))))

# %%
def plot_score_histograms(data):
    
    figure(figsize=(16,10))
    for i in range(len(METRICS)):
        subplot(6,3, i+1)
        hist(data[:, i], normed=True)
        xlim([0.0, max(1.0, np.max(data[:, i]))])
        legend([METRICS[i]])

# %%
def plot_boxes(data):
    figure(figsize=(10,8))
    for i in range(len(METRICS)):
        subplot(6, 3, i+1)
        my_data = []
        leg = []
        for k in data:
            leg.append(k)
            my_data.append(data[k][:, i])
        my_data = np.array(my_data).T
        boxplot(my_data)
        xticks(range(1, 1+len(data)), leg)
        ylim([0, max(1.0, my_data.max())])
        tight_layout()
        title(METRICS[i])

# %%
def get_top_sig(SETNAME, perfs, idx, p=0.05):
    
    # Pluck out the relevant algorithm
    data = {}
    mean = {}
    best_mean = -np.inf
    best_alg  = None
    n_algs    = len(perfs)
    
    for k in perfs:
        data[k] = perfs[k][:, idx]
        mean[k] = np.mean(data[k])
        if mean[k] > best_mean:
            best_mean = mean[k]
            best_alg = k
    
    
    
    # Compute pairwise tests against the best
    sigdiff = {}
    for k in perfs:
        if k == best_alg:
            sigdiff[k] = 1.0
            continue
        # Get the p-value
        _z, _p = scipy.stats.wilcoxon(data[best_alg], data[k])
        sigdiff[k] = _p
        
        
    # Print the results
    ordering = [(v, k) for k, v in mean.iteritems()]
    ordering.sort(reverse=True)
    
    print '%s\t%s' % (METRICS[idx], SETNAME)
    
    for (v, k) in ordering:
        print '%.3f\t%10s\t%.3e\t%r' % (v, k, sigdiff[k], sigdiff[k] * (n_algs -1) < p)

# %%
def get_worst_examples(SETNAME, perfs, algorithm, idx, k=10):
    files = sorted(map(os.path.basename, glob.glob('%s/predictions/%s/%s/*' % (ROOTPATH, SETNAME, algorithm))))
    
    
    indices = np.argsort(perfs[algorithm][:, idx])[:k]
    
    print '%s\t%s\t%s' % (METRICS[idx], SETNAME, algorithm)
    for v in indices:
        print '%.3f\t%s' % (perfs[algorithm][v, idx], files[v])

# %%
for alg in sorted(ind_perfs_beatles.keys()):
    get_worst_examples('BEATLES', ind_perfs_beatles, alg, 10, 5)
    print
# Out:
# S_F	BEATLES	dyn_sup
# 0.563	09_-_You_Never_Give_Me_Your_Money.lab
# 0.638	05_-_Dig_It.lab
# 0.671	CD2_-_06_-_Helter_Skelter.lab
# 0.710	CD1_-_06_-_The_Continuing_Story_of_Bungalow_Bill.lab
# 0.711	08_-_Love_Me_Do.lab
#
# S_F	BEATLES	dyn_unsup
# 0.585	05_-_Dig_It.lab
# 0.627	09_-_You_Never_Give_Me_Your_Money.lab
# 0.676	10_-_Sun_King.lab
# 0.676	CD2_-_06_-_Helter_Skelter.lab
# 0.681	02_-_Misery.lab
#
# S_F	BEATLES	fda
# 0.544	12_-_Sgt._Pepper's_Lonely_Hearts_Club_Band_(Reprise).lab
# 0.633	05_-_Dig_It.lab
# 0.657	CD2_-_06_-_Helter_Skelter.lab
# 0.660	11_-_Mean_Mr_Mustard.lab
# 0.668	09_-_You_Never_Give_Me_Your_Money.lab
#
# S_F	BEATLES	smga1
# 0.455	07_-_Maggie_Mae.lab
# 0.574	09_-_You_Never_Give_Me_Your_Money.lab
# 0.657	12_-_Polythene_Pam.lab
# 0.676	10_-_Baby_It's_You.lab
# 0.693	11_-_Mean_Mr_Mustard.lab
#
# S_F	BEATLES	smga2
# 0.170	CD1_-_05_-_Wild_Honey_Pie.lab
# 0.480	07_-_Maggie_Mae.lab
# 0.577	09_-_You_Never_Give_Me_Your_Money.lab
# 0.592	05_-_Dig_It.lab
# 0.665	12_-_Sgt._Pepper's_Lonely_Hearts_Club_Band_(Reprise).lab

# %%
perfs_beatles = evaluate_set('BEATLES')
# Out:
# Scoring dyn_sup...
# Scoring dyn_unsup...
# Scoring fda...
# Scoring smga1...
# Scoring smga2...

# %%
pprint(perfs_beatles)
# Out:
# {'dyn_sup': array([ 0.43825356,  0.44670459,  0.43350718,  0.6854502 ,  0.6799208 ,
#         0.67029219,  1.58040503,  1.66081844,  0.82843256,  0.80788547,
#         0.81250808,  0.74386256,  0.68636847,  0.69429264,  1.62954386,
#         0.74151553,  0.79573146,  0.64053887]),
#  'dyn_unsup': array([ 0.44649753,  0.39024802,  0.40839598,  0.70404795,  0.60299652,
#         0.63965541,  2.25708101,  1.66484078,  0.8421878 ,  0.75480598,
#         0.79083483,  0.77975071,  0.61305882,  0.66843458,  1.51000334,
#         0.70599802,  0.77312011,  0.60512691]),
#  'fda': array([ 0.45475801,  0.41627385,  0.4266804 ,  0.68783651,  0.6199748 ,
#         0.64236863,  1.95303352,  1.68265363,  0.83859637,  0.7780151 ,
#         0.80198129,  0.77447693,  0.65325685,  0.69063416,  1.5637948 ,
#         0.72690501,  0.78873552,  0.63322578]),
#  'smga1': array([ 0.35848177,  0.39340451,  0.36953244,  0.76901394,  0.80811573,
#         0.78046769,  1.15248184,  1.62451732,  0.81082868,  0.85842994,
#         0.82897101,  0.70173186,  0.79827864,  0.72933496,  1.75718127,
#         0.76488214,  0.81191025,  0.68312399]),
#  'smga2': array([ 0.3338195 ,  0.3671374 ,  0.34389022,  0.74448069,  0.74567912,
#         0.7362441 ,  1.43455084,  1.65903464,  0.80738387,  0.83273754,
#         0.81257208,  0.69613841,  0.75846218,  0.7052857 ,  1.70208372,
#         0.74671145,  0.79177247,  0.65213521])}

# %%
save_results('/home/bmcfee/git/olda/data/beatles_scores.csv', perfs_beatles)

# %%
ind_perfs_beatles = evaluate_set('BEATLES', agg=False)
# Out:
# Scoring dyn_sup...
# Scoring dyn_unsup...
# Scoring fda...
# Scoring smga1...
# Scoring smga2...

# %%
for idx in range(len(METRICS)):
    get_top_sig('BEATLES', ind_perfs_beatles, idx=idx)
    print
# Out:
# BD.5 P	BEATLES
# 0.455	       fda	1.000e+00	False
# 0.446	 dyn_unsup	6.435e-01	False
# 0.438	   dyn_sup	5.380e-03	True
# 0.358	     smga1	1.034e-11	True
#
# BD.5 R	BEATLES
# 0.447	   dyn_sup	1.000e+00	False
# 0.416	       fda	4.247e-05	True
# 0.393	     smga1	4.100e-06	True
# 0.390	 dyn_unsup	7.729e-10	True
#
# BD.5 F	BEATLES
# 0.434	   dyn_sup	1.000e+00	False
# 0.427	       fda	4.925e-01	False
# 0.408	 dyn_unsup	3.264e-04	True
# 0.370	     smga1	5.400e-09	True
#
# BD3 P	BEATLES
# 0.769	     smga1	1.000e+00	False
# 0.704	 dyn_unsup	1.052e-06	True
# 0.688	       fda	6.272e-08	True
# 0.685	   dyn_sup	3.429e-09	True
#
# BD3 R	BEATLES
# 0.808	     smga1	1.000e+00	False
# 0.680	   dyn_sup	2.759e-12	True
# 0.620	       fda	1.022e-18	True
# 0.603	 dyn_unsup	1.035e-20	True
#
# BD3 F	BEATLES
# 0.780	     smga1	1.000e+00	False
# 0.670	   dyn_sup	3.877e-13	True
# 0.642	       fda	2.828e-16	True
# 0.640	 dyn_unsup	2.820e-16	True
#
# BDev T2P	BEATLES
# 2.257	 dyn_unsup	1.000e+00	False
# 1.953	       fda	2.536e-02	False
# 1.580	   dyn_sup	9.191e-13	True
# 1.152	     smga1	4.065e-13	True
#
# BDev P2T	BEATLES
# 1.683	       fda	1.000e+00	False
# 1.665	 dyn_unsup	4.661e-01	False
# 1.661	   dyn_sup	3.040e-02	False
# 1.625	     smga1	2.813e-01	False
#
# S_O	BEATLES
# 0.842	 dyn_unsup	1.000e+00	False
# 0.839	       fda	6.314e-01	False
# 0.828	   dyn_sup	3.683e-04	True
# 0.811	     smga1	2.156e-08	True
#
# S_U	BEATLES
# 0.858	     smga1	1.000e+00	False
# 0.808	   dyn_sup	2.140e-12	True
# 0.778	       fda	5.366e-21	True
# 0.755	 dyn_unsup	4.893e-24	True
#
# S_F	BEATLES
# 0.829	     smga1	1.000e+00	False
# 0.813	   dyn_sup	3.014e-04	True
# 0.802	       fda	1.603e-07	True
# 0.791	 dyn_unsup	7.333e-11	True
#
# Pair_P	BEATLES
# 0.780	 dyn_unsup	1.000e+00	False
# 0.774	       fda	9.073e-01	False
# 0.744	   dyn_sup	3.073e-07	True
# 0.702	     smga1	1.185e-12	True
#
# Pair_R	BEATLES
# 0.798	     smga1	1.000e+00	False
# 0.686	   dyn_sup	5.990e-16	True
# 0.653	       fda	4.476e-22	True
# 0.613	 dyn_unsup	9.444e-25	True
#
# Pair_F	BEATLES
# 0.729	     smga1	1.000e+00	False
# 0.694	   dyn_sup	4.102e-04	True
# 0.691	       fda	1.702e-04	True
# 0.668	 dyn_unsup	1.318e-07	True
#
# MI	BEATLES
# 1.757	     smga1	1.000e+00	False
# 1.630	   dyn_sup	8.840e-14	True
# 1.564	       fda	5.927e-22	True
# 1.510	 dyn_unsup	8.896e-25	True
#
# AMI	BEATLES
# 0.765	     smga1	1.000e+00	False
# 0.742	   dyn_sup	2.201e-04	True
# 0.727	       fda	1.943e-06	True
# 0.706	 dyn_unsup	1.088e-09	True
#
# NMI	BEATLES
# 0.812	     smga1	1.000e+00	False
# 0.796	   dyn_sup	3.657e-04	True
# 0.789	       fda	2.147e-06	True
# 0.773	 dyn_unsup	4.988e-11	True
#
# ARI	BEATLES
# 0.683	     smga1	1.000e+00	False
# 0.641	   dyn_sup	1.350e-04	True
# 0.633	       fda	1.985e-05	True
# 0.605	 dyn_unsup	8.613e-09	True

# %%
plot_boxes(ind_perfs_beatles)

# %%
perfs_salami = evaluate_set('SALAMI', agg=True)

# %%
pprint(perfs_salami)

# %%
save_results('/home/bmcfee/git/olda/data/salami_score.csv', perfs_salami)

# %%
ind_perfs_salami = evaluate_set('SALAMI', agg=False)

# %%
for idx in range(len(METRICS)):
    get_top_sig('SALAMI', ind_perfs_salami, idx=idx)
    print

# %%
plot_boxes(ind_perfs_salami)

# %% [markdown]
# # Figures

# %%
import librosa
import scipy.signal
import functools

# %%
def get_beat_mfccs(filename):
    y, sr = librosa.load(filename)
    
    S = librosa.feature.melspectrogram(y, sr, n_fft=2048, hop_length=64, n_mels=128, fmax=8000)
    
    tempo, beats = librosa.beat.beat_track(y, sr, n_fft=2048, hop_length=64)
    
    M = librosa.feature.mfcc(S, d=32)
    M = librosa.feature.sync(M, beats)
    return M

# %%
def compress_data(X, k):
    sigma = np.cov(X)
    e_vals, e_vecs = scipy.linalg.eig(sigma)
        
    e_vals = np.maximum(0.0, np.real(e_vals))
    e_vecs = np.real(e_vecs)
        
    idx = np.argsort(e_vals)[::-1]
        
    e_vals = e_vals[idx]
    e_vecs = e_vecs[:, idx]
        
    # Truncate to k dimensions
    if k < len(e_vals):
        e_vals = e_vals[:k]
        e_vecs = e_vecs[:, :k]
        
    # Normalize by the leading singular value of X
    Z = np.sqrt(e_vals.max())
        
    if Z > 0:
        e_vecs = e_vecs / Z
        
    return e_vecs.T.dot(X)

# %%
def make_rep_feature_plot(M):
    
    myimshow = functools.partial(imshow, aspect='auto', interpolation='none', origin='lower', cmap='gray_r')
    
    R = librosa.segment.recurrence_matrix(M, k=np.sqrt(1./M.shape[1]), sym=False).astype(np.float)
    
    Rskew = librosa.segment.structure_feature(R, pad=True)
    Rskew = np.roll(Rskew, M.shape[1], axis=0)
    
    
    Rfilt = scipy.signal.medfilt2d(Rskew, kernel_size=(1, 7))
    #Rfilt = Rfilt[Rfilt.sum(axis=1) > 0, :]
    
    Rlatent = compress_data(Rfilt, 8)
    
    figure(figsize=(6,6))
    subplot(221)
    myimshow(R), title('Self-similarity')
    xlabel('Beat'), ylabel('Beat')
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    yticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(222)
    myimshow(Rskew), title('Skewed similarity')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1], M.shape[1] + 1, Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(223)
    myimshow(Rfilt), title('Median-filtering')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1], M.shape[1] + 1, Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(224)
    myimshow(Rlatent, origin='upper', cmap='PRGn_r'), title('Latent repetition')
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    xlabel('Beat'), ylabel('Factor')
    tight_layout()
    
    savefig('/home/bmcfee/git/olda/paper/figs/rep.pdf', format='pdf', pad_inches=0, transparent=True)

# %%
M = get_beat_mfccs('/home/bmcfee/data/CAL500/mp3/2pac-trapped.mp3')

# %%
make_rep_feature_plot(M[:,:150])

# %%
model_beatles = np.load('/home/bmcfee/git/olda/data/model_olda_beatles.npy')
model_salami  = np.load('/home/bmcfee/git/olda/data/model_olda_salami.npy')
figure(figsize=(4,3.5))
subplot(211)
imshow(model_beatles, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('Beatles-ISO')
yticks([])
#ylabel("More important $\\rightarrow$")
#xticks([0, 32, 44, 76, 108], ['MFCC', 'Chroma', 'Rep-M', 'Rep-C', 'Time'], rotation=-30, horizontalalignment='left')
xticks([])
#colorbar()

subplot(212)
imshow(model_salami, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('SALAMI-free')
#colorbar(orientation='horizontal')
#ylabel("More important $\\rightarrow$")
yticks([])
xticks([0, 32, 44, 76, 108], ['MFCC', '$\uparrow$\nChroma', 'R-MFCC', 'R-Chroma', 'Time'], horizontalalignment='left')

tight_layout()
savefig('/home/bmcfee/git/olda/paper/figs/w.pdf', format='pdf', pad_inches=0, transparent=True)

# %%
model_fda_beatles = np.load('/home/bmcfee/git/olda/data/model_fda_beatles.npy')
model_olda_beatles  = np.load('/home/bmcfee/git/olda/data/model_olda_beatles.npy')
figure(figsize=(4,3))
subplot(211)
imshow(model_fda_beatles, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('FDA')
yticks([])
#ylabel("More important $\\rightarrow$")
#xticks([0, 32, 44, 76, 108], ['MFCC', 'Chroma', 'Rep-M', 'Rep-C', 'Time'], rotation=-30, horizontalalignment='left')
xticks([])
#colorbar()

subplot(212)
imshow(model_salami, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('OLDA')
#colorbar(orientation='horizontal')
#ylabel("More important $\\rightarrow$")
yticks([])
xticks([0, 32, 44, 76, 108], ['MFCC', '$\uparrow$\nChroma', 'R-MFCC', 'R-Chroma', 'Time'], horizontalalignment='left')

tight_layout()
savefig('/home/bmcfee/git/olda/paper/figs/fda-vs-olda.pdf', format='pdf', pad_inches=0, transparent=True)
