# %%
import mir_eval
import sys
import os
import glob
import numpy as np
from pprint import pprint
import scipy.stats

# %%
ROOTPATH = '/home/bmcfee/git/olda/data/'

# %%
def load_annotations(path):
    
    files = sorted(glob.glob(path))
    
    data = [mir_eval.util.import_segment_boundaries(f) for f in files]
    
    return data

# %%
def evaluate_set(SETNAME, agg=True):
    
    truth = load_annotations('%s/truth/%s/*' % (ROOTPATH, SETNAME))
    
    algos = map(os.path.basename, sorted(glob.glob('%s/predictions/%s/*' % (ROOTPATH, SETNAME))))
    
    scores = {}
    for A in algos:
        print 'Scoring %s...' % A
        # Load the corresponding predictions
        predictions = load_annotations('%s/predictions/%s/%s/*' % (ROOTPATH, SETNAME, A))
        
        # Scrub the predictions to valid ranges
        for i in range(len(predictions)):
            predictions[i] = mir_eval.util.adjust_segment_boundaries(predictions[i], t_max=truth[i][-1])
            
        # Compute metrics
        my_scores = []
        
        for t, p in zip(truth, predictions):
            S = []
            S.extend(mir_eval.segment.boundary_detection(t, p, window=0.5))
            S.extend(mir_eval.segment.boundary_detection(t, p, window=3.0))
            S.extend(mir_eval.segment.boundary_deviation(t, p))
            S.extend(mir_eval.segment.frame_clustering_nce(t, p))
            S.extend(mir_eval.segment.frame_clustering_pairwise(t, p))
            S.extend(mir_eval.segment.frame_clustering_mutual_information(t, p))
            S.append(mir_eval.segment.frame_clustering_rand(t, p))
            my_scores.append(S)
            
        my_scores = np.array(my_scores)
        if agg:
            scores[A] = np.mean(my_scores, axis=0)
        else:
            scores[A] = my_scores
        
    return scores

# %%
METRICS = ['BD.5 P', 'BD.5 R', 'BD.5 F', 
           'BD3 P', 'BD3 R', 'BD3 F', 
           'BDev T2P', 'BDev P2T', 
           'S_O', 'S_U', 'S_F', 
           'Pair_P', 'Pair_R', 'Pair_F', 
           'MI', 'AMI', 'NMI', 'ARI']

# %%
def save_results(outfile, predictions):
    
    with open(outfile, 'w') as f:
        f.write('%s,%s\n' % ('Algorithm', ','.join(METRICS)))
        
        for k in predictions:
            f.write('%s,%s\n' % (k, ','.join(map(lambda x: '%.8f' % x, predictions[k]))))

# %%
def plot_score_histograms(data):
    
    figure(figsize=(16,10))
    for i in range(len(METRICS)):
        subplot(6,3, i+1)
        hist(data[:, i], normed=True)
        xlim([0.0, max(1.0, np.max(data[:, i]))])
        legend([METRICS[i]])

# %%
def plot_boxes(data):
    figure(figsize=(10,8))
    for i in range(len(METRICS)):
        subplot(6, 3, i+1)
        my_data = []
        leg = []
        for k in data:
            leg.append(k)
            my_data.append(data[k][:, i])
        my_data = np.array(my_data).T
        boxplot(my_data)
        xticks(range(1, 1+len(data)), leg)
        ylim([0, max(1.0, my_data.max())])
        tight_layout()
        title(METRICS[i])

# %%
def get_top_sig(SETNAME, perfs, idx, p=0.05):
    
    # Pluck out the relevant algorithm
    data = {}
    mean = {}
    best_mean = -np.inf
    best_alg  = None
    n_algs    = len(perfs)
    
    for k in perfs:
        data[k] = perfs[k][:, idx]
        mean[k] = np.mean(data[k])
        if mean[k] > best_mean:
            best_mean = mean[k]
            best_alg = k
    
    
    
    # Compute pairwise tests against the best
    sigdiff = {}
    for k in perfs:
        if k == best_alg:
            sigdiff[k] = 1.0
            continue
        # Get the p-value
        _z, _p = scipy.stats.wilcoxon(data[best_alg], data[k])
        sigdiff[k] = _p
        
        
    # Print the results
    ordering = [(v, k) for k, v in mean.iteritems()]
    ordering.sort(reverse=True)
    
    print '%s\t%s' % (METRICS[idx], SETNAME)
    
    for (v, k) in ordering:
        print '%.3f\t%10s\t%.3e\t%r' % (v, k, sigdiff[k], sigdiff[k] * (n_algs -1) < p)

# %%
def get_worst_examples(SETNAME, perfs, algorithm, idx, k=10):
    files = sorted(map(os.path.basename, glob.glob('%s/predictions/%s/%s/*' % (ROOTPATH, SETNAME, algorithm))))
    
    
    indices = np.argsort(perfs[algorithm][:, idx])[:k]
    
    print '%s\t%s\t%s' % (METRICS[idx], SETNAME, algorithm)
    for v in indices:
        print '%.3f\t%s' % (perfs[algorithm][v, idx], files[v])

# %%
for alg in sorted(ind_perfs_beatles.keys()):
    get_worst_examples('BEATLES', ind_perfs_beatles, alg, 5, 10)
    print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-a6b25c3502fc> in <module>()
# ----> 1 for alg in sorted(ind_perfs_beatles.keys()):
#       2     get_worst_examples('BEATLES', ind_perfs_beatles, alg, 5, 10)
#       3     print
#
# NameError: name 'ind_perfs_beatles' is not defined

# %%
perfs_beatles = evaluate_set('BEATLES')
# Out:
# Scoring fda...
# Scoring olda...
# Scoring smga1...
# Scoring unsup...

# %%
pprint(perfs_beatles)
# Out:
# {'fda': array([ 0.27471483,  0.20763848,  0.22933717,  0.58237745,  0.43033907,
#         0.48311669,  4.71457542,  3.23557542,  0.83859637,  0.7780151 ,
#         0.80198129,  0.77447693,  0.65325685,  0.69063416,  1.5637948 ,
#         0.72690501,  0.78873552,  0.63322578]),
#  'olda': array([ 0.29901012,  0.29612842,  0.28851372,  0.60059332,  0.57710736,
#         0.57283737,  2.86147486,  2.88162849,  0.82843256,  0.80788547,
#         0.81250808,  0.74386256,  0.68636847,  0.69429264,  1.62954386,
#         0.74151553,  0.79573146,  0.64053887]),
#  'smga1': array([ 0.14716361,  0.17188831,  0.15561933,  0.62729373,  0.72829904,
#         0.66129793,  1.86143128,  3.12297011,  0.81082868,  0.85842994,
#         0.82897101,  0.70173186,  0.79827864,  0.72933496,  1.75718127,
#         0.76488214,  0.81191025,  0.68312399]),
#  'unsup': array([ 0.27440795,  0.2179763 ,  0.23658021,  0.60619502,  0.46894749,
#         0.51780621,  4.37074302,  3.03534358,  0.8421878 ,  0.75480598,
#         0.79083483,  0.77975071,  0.61305882,  0.66843458,  1.51000334,
#         0.70599802,  0.77312011,  0.60512691])}

# %%
save_results('/home/bmcfee/git/olda/data/beatles_scores_adjusted.csv', perfs_beatles)

# %%
ind_perfs_beatles = evaluate_set('BEATLES', agg=False)
# Out:
# Scoring fda...
# Scoring olda...
# Scoring smga1...
# Scoring unsup...

# %%
for idx in range(len(METRICS)):
    get_top_sig('BEATLES', ind_perfs_beatles, idx=idx)
    print
# Out:
# BD.5 P	BEATLES
# 0.299	      olda	1.000e+00	False
# 0.275	       fda	6.587e-03	True
# 0.274	     unsup	7.752e-03	True
# 0.147	     smga1	6.836e-18	True
#
# BD.5 R	BEATLES
# 0.296	      olda	1.000e+00	False
# 0.218	     unsup	1.205e-10	True
# 0.208	       fda	1.523e-12	True
# 0.172	     smga1	6.910e-12	True
#
# BD.5 F	BEATLES
# 0.289	      olda	1.000e+00	False
# 0.237	     unsup	2.527e-07	True
# 0.229	       fda	1.021e-08	True
# 0.156	     smga1	2.103e-15	True
#
# BD3 P	BEATLES
# 0.627	     smga1	1.000e+00	False
# 0.606	     unsup	3.168e-02	False
# 0.601	      olda	1.569e-02	True
# 0.582	       fda	2.255e-03	True
#
# BD3 R	BEATLES
# 0.728	     smga1	1.000e+00	False
# 0.577	      olda	4.567e-12	True
# 0.469	     unsup	1.146e-20	True
# 0.430	       fda	3.451e-23	True
#
# BD3 F	BEATLES
# 0.661	     smga1	1.000e+00	False
# 0.573	      olda	3.701e-08	True
# 0.518	     unsup	2.157e-13	True
# 0.483	       fda	2.486e-16	True
#
# BDev T2P	BEATLES
# 4.715	       fda	1.000e+00	False
# 4.371	     unsup	5.049e-02	False
# 2.861	      olda	4.273e-19	True
# 1.861	     smga1	2.134e-21	True
#
# BDev P2T	BEATLES
# 3.236	       fda	1.000e+00	False
# 3.123	     smga1	2.781e-01	False
# 3.035	     unsup	3.540e-01	False
# 2.882	      olda	1.036e-03	True
#
# S_O	BEATLES
# 0.842	     unsup	1.000e+00	False
# 0.839	       fda	6.314e-01	False
# 0.828	      olda	3.683e-04	True
# 0.811	     smga1	2.156e-08	True
#
# S_U	BEATLES
# 0.858	     smga1	1.000e+00	False
# 0.808	      olda	2.140e-12	True
# 0.778	       fda	5.366e-21	True
# 0.755	     unsup	4.893e-24	True
#
# S_F	BEATLES
# 0.829	     smga1	1.000e+00	False
# 0.813	      olda	3.014e-04	True
# 0.802	       fda	1.603e-07	True
# 0.791	     unsup	7.333e-11	True
#
# Pair_P	BEATLES
# 0.780	     unsup	1.000e+00	False
# 0.774	       fda	9.073e-01	False
# 0.744	      olda	3.073e-07	True
# 0.702	     smga1	1.185e-12	True
#
# Pair_R	BEATLES
# 0.798	     smga1	1.000e+00	False
# 0.686	      olda	5.990e-16	True
# 0.653	       fda	4.476e-22	True
# 0.613	     unsup	9.444e-25	True
#
# Pair_F	BEATLES
# 0.729	     smga1	1.000e+00	False
# 0.694	      olda	4.102e-04	True
# 0.691	       fda	1.702e-04	True
# 0.668	     unsup	1.318e-07	True
#
# MI	BEATLES
# 1.757	     smga1	1.000e+00	False
# 1.630	      olda	8.840e-14	True
# 1.564	       fda	5.927e-22	True
# 1.510	     unsup	8.896e-25	True
#
# AMI	BEATLES
# 0.765	     smga1	1.000e+00	False
# 0.742	      olda	2.201e-04	True
# 0.727	       fda	1.943e-06	True
# 0.706	     unsup	1.088e-09	True
#
# NMI	BEATLES
# 0.812	     smga1	1.000e+00	False
# 0.796	      olda	3.657e-04	True
# 0.789	       fda	2.147e-06	True
# 0.773	     unsup	4.988e-11	True
#
# ARI	BEATLES
# 0.683	     smga1	1.000e+00	False
# 0.641	      olda	1.350e-04	True
# 0.633	       fda	1.985e-05	True
# 0.605	     unsup	8.613e-09	True

# %%
plot_boxes(ind_perfs_beatles)

# %%
perfs_salami = evaluate_set('SALAMI', agg=True)
# Out:
# Scoring CNMF...
# Scoring SIPLCA...
# Scoring fda...
# Scoring olda...
# Scoring smga1...
# Scoring unsup...

# %%
pprint(perfs_salami)
# Out:
# {'CNMF': array([ 0.10514414,  0.13322015,  0.10971976,  0.45024537,  0.54333524,
#         0.46309017,  4.1670073 ,  5.94623858,  0.76659964,  0.7972802 ,
#         0.76675763,  0.57638598,  0.63895335,  0.55031555,  1.77360763,
#         0.66952316,  0.74624826,  0.49008302]),
#  'SIPLCA': array([  0.2100008 ,   0.10169394,   0.12774307,   0.45112871,
#          0.22782295,   0.28610934,  16.93411006,   5.80685512,
#          0.8733449 ,   0.53755385,   0.64316976,   0.8135197 ,
#          0.36192509,   0.45888541,   1.1118125 ,   0.4785737 ,
#          0.6205327 ,   0.34372012]),
#  'fda': array([  0.2964591 ,   0.16567407,   0.20532428,   0.56362742,
#          0.32996422,   0.40007574,  11.005866  ,   5.32424189,
#          0.84887349,   0.72860594,   0.77148939,   0.75103374,
#          0.56559308,   0.6032437 ,   1.60012483,   0.67120102,
#          0.75986737,   0.53586001]),
#  'olda': array([ 0.26451753,  0.23356139,  0.24062336,  0.509824  ,  0.45726457,
#         0.46674448,  5.02011253,  5.31143702,  0.80359902,  0.82920576,
#         0.80764684,  0.64026419,  0.7065894 ,  0.63996999,  1.85299536,
#         0.74285179,  0.79730807,  0.5913344 ]),
#  'smga1': array([ 0.11493075,  0.17796945,  0.13437579,  0.43375133,  0.6661867 ,
#         0.5076943 ,  2.09821367,  7.15111203,  0.71435089,  0.89521267,
#         0.78623916,  0.4482276 ,  0.82188953,  0.55046362,  2.02822911,
#         0.68987443,  0.78058019,  0.50768952]),
#  'unsup': array([ 0.23626804,  0.18376692,  0.20024696,  0.49480303,  0.39041467,
#         0.42247663,  7.14079917,  5.71324844,  0.81152191,  0.79504053,
#         0.79440671,  0.66614262,  0.65239495,  0.62641201,  1.76518036,
#         0.72299861,  0.78253875,  0.57230772])}

# %%
save_results('/home/bmcfee/git/olda/data/salami_scores_adjusted.csv', perfs_salami)

# %%
ind_perfs_salami = evaluate_set('SALAMI', agg=False)
# Out:
# Scoring CNMF...
# Scoring SIPLCA...
# Scoring fda...
# Scoring olda...
# Scoring smga1...
# Scoring unsup...

# %%
for alg in sorted(ind_perfs_beatles.keys()):
    get_worst_examples('SALAMI', ind_perfs_salami, alg, 10, 5)
    print
# Out:
# S_F	SALAMI	fda
# 0.000	964.lab
# 0.354	1376.lab
# 0.458	1462.lab
# 0.514	1256.lab
# 0.569	1226.lab
#
# S_F	SALAMI	olda
# 0.000	964.lab
# 0.201	1376.lab
# 0.420	1462.lab
# 0.505	1226.lab
# 0.631	1062.lab
#
# S_F	SALAMI	smga1
# 0.000	964.lab
# 0.203	1376.lab
# 0.349	1462.lab
# 0.495	1226.lab
# 0.540	1062.lab
#
# S_F	SALAMI	unsup
# 0.000	964.lab
# 0.253	1376.lab
# 0.435	1462.lab
# 0.555	1226.lab
# 0.618	1062.lab

# %%
for idx in range(len(METRICS)):
    get_top_sig('SALAMI', ind_perfs_salami, idx=idx)
    print
# Out:
# BD.5 P	SALAMI
# 0.296	       fda	1.000e+00	False
# 0.265	      olda	2.057e-04	True
# 0.236	     unsup	3.759e-10	True
# 0.210	    SIPLCA	3.882e-10	True
# 0.115	     smga1	1.083e-34	True
# 0.105	      CNMF	6.959e-33	True
#
# BD.5 R	SALAMI
# 0.234	      olda	1.000e+00	False
# 0.184	     unsup	3.518e-13	True
# 0.178	     smga1	2.172e-08	True
# 0.166	       fda	3.775e-13	True
# 0.133	      CNMF	1.670e-17	True
# 0.102	    SIPLCA	1.712e-25	True
#
# BD.5 F	SALAMI
# 0.241	      olda	1.000e+00	False
# 0.205	       fda	1.918e-06	True
# 0.200	     unsup	1.796e-09	True
# 0.134	     smga1	1.442e-23	True
# 0.128	    SIPLCA	3.702e-22	True
# 0.110	      CNMF	1.985e-27	True
#
# BD3 P	SALAMI
# 0.564	       fda	1.000e+00	False
# 0.510	      olda	1.538e-07	True
# 0.495	     unsup	1.063e-11	True
# 0.451	    SIPLCA	2.357e-13	True
# 0.450	      CNMF	3.171e-15	True
# 0.434	     smga1	9.603e-23	True
#
# BD3 R	SALAMI
# 0.666	     smga1	1.000e+00	False
# 0.543	      CNMF	2.962e-16	True
# 0.457	      olda	2.589e-29	True
# 0.390	     unsup	5.530e-36	True
# 0.330	       fda	6.142e-41	True
# 0.228	    SIPLCA	6.965e-42	True
#
# BD3 F	SALAMI
# 0.508	     smga1	1.000e+00	False
# 0.467	      olda	2.000e-06	True
# 0.463	      CNMF	2.547e-07	True
# 0.422	     unsup	9.682e-15	True
# 0.400	       fda	6.414e-19	True
# 0.286	    SIPLCA	3.554e-34	True
#
# BDev T2P	SALAMI
# 16.934	    SIPLCA	1.000e+00	False
# 11.006	       fda	7.111e-13	True
# 7.141	     unsup	1.131e-30	True
# 5.020	      olda	1.435e-38	True
# 4.167	      CNMF	3.119e-41	True
# 2.098	     smga1	3.570e-43	True
#
# BDev P2T	SALAMI
# 7.151	     smga1	1.000e+00	False
# 5.946	      CNMF	4.591e-03	True
# 5.807	    SIPLCA	5.163e-04	True
# 5.713	     unsup	3.249e-10	True
# 5.324	       fda	1.708e-15	True
# 5.311	      olda	3.175e-14	True
#
# S_O	SALAMI
# 0.873	    SIPLCA	1.000e+00	False
# 0.849	       fda	2.295e-04	True
# 0.812	     unsup	4.938e-28	True
# 0.804	      olda	1.418e-31	True
# 0.767	      CNMF	2.641e-37	True
# 0.714	     smga1	3.834e-43	True
#
# S_U	SALAMI
# 0.895	     smga1	1.000e+00	False
# 0.829	      olda	7.552e-36	True
# 0.797	      CNMF	1.069e-37	True
# 0.795	     unsup	3.279e-41	True
# 0.729	       fda	5.271e-43	True
# 0.538	    SIPLCA	4.407e-43	True
#
# S_F	SALAMI
# 0.808	      olda	1.000e+00	False
# 0.794	     unsup	2.627e-11	True
# 0.786	     smga1	1.067e-10	True
# 0.771	       fda	3.312e-18	True
# 0.767	      CNMF	7.179e-22	True
# 0.643	    SIPLCA	1.485e-36	True
#
# Pair_P	SALAMI
# 0.814	    SIPLCA	1.000e+00	False
# 0.751	       fda	1.018e-07	True
# 0.666	     unsup	1.516e-33	True
# 0.640	      olda	4.381e-37	True
# 0.576	      CNMF	1.053e-36	True
# 0.448	     smga1	2.987e-43	True
#
# Pair_R	SALAMI
# 0.822	     smga1	1.000e+00	False
# 0.707	      olda	1.829e-32	True
# 0.652	     unsup	4.229e-39	True
# 0.639	      CNMF	1.191e-35	True
# 0.566	       fda	3.205e-42	True
# 0.362	    SIPLCA	5.271e-43	True
#
# Pair_F	SALAMI
# 0.640	      olda	1.000e+00	False
# 0.626	     unsup	4.028e-04	True
# 0.603	       fda	1.205e-06	True
# 0.550	     smga1	1.959e-25	True
# 0.550	      CNMF	2.491e-20	True
# 0.459	    SIPLCA	2.326e-28	True
#
# MI	SALAMI
# 2.028	     smga1	1.000e+00	False
# 1.853	      olda	2.963e-36	True
# 1.774	      CNMF	9.552e-38	True
# 1.765	     unsup	2.186e-41	True
# 1.600	       fda	3.613e-43	True
# 1.112	    SIPLCA	3.059e-43	True
#
# AMI	SALAMI
# 0.743	      olda	1.000e+00	False
# 0.723	     unsup	4.442e-11	True
# 0.690	     smga1	1.924e-18	True
# 0.671	       fda	1.953e-21	True
# 0.670	      CNMF	2.107e-24	True
# 0.479	    SIPLCA	4.404e-39	True
#
# NMI	SALAMI
# 0.797	      olda	1.000e+00	False
# 0.783	     unsup	7.155e-13	True
# 0.781	     smga1	6.243e-07	True
# 0.760	       fda	4.223e-20	True
# 0.746	      CNMF	1.398e-27	True
# 0.621	    SIPLCA	1.425e-40	True
#
# ARI	SALAMI
# 0.591	      olda	1.000e+00	False
# 0.572	     unsup	1.200e-05	True
# 0.536	       fda	2.154e-10	True
# 0.508	     smga1	4.300e-22	True
# 0.490	      CNMF	1.392e-21	True
# 0.344	    SIPLCA	1.500e-33	True

# %%
plot_boxes(ind_perfs_salami)

# %% [markdown]
# # Figures

# %%
import librosa
import scipy.signal
import functools

# %%
def get_beat_mfccs(filename):
    y, sr = librosa.load(filename)
    
    S = librosa.feature.melspectrogram(y, sr, n_fft=2048, hop_length=64, n_mels=128, fmax=8000)
    
    tempo, beats = librosa.beat.beat_track(y, sr, n_fft=2048, hop_length=64)
    
    M = librosa.feature.mfcc(librosa.logamplitude(S), d=32)
    M = librosa.feature.sync(M, beats)
    return M

# %%
def compress_data(X, k):
    sigma = np.cov(X)
    e_vals, e_vecs = scipy.linalg.eig(sigma)
        
    e_vals = np.maximum(0.0, np.real(e_vals))
    e_vecs = np.real(e_vecs)
        
    idx = np.argsort(e_vals)[::-1]
        
    e_vals = e_vals[idx]
    e_vecs = e_vecs[:, idx]
        
    # Truncate to k dimensions
    if k < len(e_vals):
        e_vals = e_vals[:k]
        e_vecs = e_vecs[:, :k]
        
    # Normalize by the leading singular value of X
    Z = np.sqrt(e_vals.max())
        
    if Z > 0:
        e_vecs = e_vecs / Z
        
    return e_vecs.T.dot(X)

# %%
def make_rep_feature_plot(M):
    
    myimshow = functools.partial(imshow, aspect='auto', interpolation='none', origin='lower', cmap='gray_r')
    
    R = librosa.segment.recurrence_matrix(M, k=2*np.sqrt(1./M.shape[1]), sym=False).astype(np.float)
    
    Rskew = librosa.segment.structure_feature(R, pad=True)
    Rskew = np.roll(Rskew, M.shape[1], axis=0)
    
    
    Rfilt = scipy.signal.medfilt2d(Rskew, kernel_size=(1, 7))
    #Rfilt = Rfilt[Rfilt.sum(axis=1) > 0, :]
    
    Rlatent = compress_data(Rfilt, 8)
    #Rlatent = compress_data(Rfilt, R.shape[0])
    
    figure(figsize=(6,6))
    subplot(221)
    myimshow(R), title('Self-similarity')
    xlabel('Beat'), ylabel('Beat')
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    yticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(222)
    myimshow(Rskew), title('Skewed self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(223)
    myimshow(Rfilt), title('Filtered self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(224)
    myimshow(Rlatent, origin='upper', cmap='PRGn_r'), title('Latent repetition')
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    xlabel('Beat'), ylabel('Factor')
    tight_layout()
    
    savefig('/home/bmcfee/git/olda/paper/figs/rep.pdf', format='pdf', pad_inches=0, transparent=True)
    #savefig('/home/bmcfee/git/olda/paper/figs/rep.svg', format='svg', pad_inches=0, transparent=True, dpi=200)

# %%
M = get_beat_mfccs('/home/bmcfee/data/CAL500/mp3/2pac-trapped.mp3')

# %%
make_rep_feature_plot(M[:,40:137])

# %%
model_beatles = np.load('/home/bmcfee/git/olda/data/model_olda_beatles.npy')
model_salami  = np.load('/home/bmcfee/git/olda/data/model_olda_salami.npy')
figure(figsize=(4,3.5))
subplot(211)
imshow(model_beatles, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('Beatles-ISO')
yticks([])
#ylabel("More important $\\rightarrow$")
#xticks([0, 32, 44, 76, 108], ['MFCC', 'Chroma', 'Rep-M', 'Rep-C', 'Time'], rotation=-30, horizontalalignment='left')
xticks([])
#colorbar()

subplot(212)
imshow(model_salami, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('SALAMI-free')
#colorbar(orientation='horizontal')
#ylabel("More important $\\rightarrow$")
yticks([])
xticks([0, 32, 44, 76, 108], ['MFCC', '$\uparrow$\nChroma', 'R-MFCC', 'R-Chroma', 'Time'], horizontalalignment='left')

tight_layout()
savefig('/home/bmcfee/git/olda/paper/figs/w.pdf', format='pdf', pad_inches=0, transparent=True)

# %%
model_fda_beatles = np.load('/home/bmcfee/git/olda/data/model_fda_beatles.npy')
model_olda_beatles  = np.load('/home/bmcfee/git/olda/data/model_olda_beatles.npy')
figure(figsize=(4,3))
subplot(211)
imshow(model_fda_beatles, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('FDA')
yticks([])
#ylabel("More important $\\rightarrow$")
#xticks([0, 32, 44, 76, 108], ['MFCC', 'Chroma', 'Rep-M', 'Rep-C', 'Time'], rotation=-30, horizontalalignment='left')
xticks([])
#colorbar()

subplot(212)
imshow(model_salami, aspect='auto', interpolation='none', cmap='PRGn_r')
ylabel('OLDA')
#colorbar(orientation='horizontal')
#ylabel("More important $\\rightarrow$")
yticks([])
xticks([0, 32, 44, 76, 108], ['MFCC', '$\uparrow$\nChroma', 'R-MFCC', 'R-Chroma', 'Time'], horizontalalignment='left')

tight_layout()
savefig('/home/bmcfee/git/olda/paper/figs/fda-vs-olda.pdf', format='pdf', pad_inches=0, transparent=True)

# %% [markdown]
# SVD stuff

# %%
def rep_feature_svd(M):
    
    myimshow = functools.partial(imshow, aspect='auto', interpolation='none', origin='lower', cmap='gray_r')
    
    R = librosa.segment.recurrence_matrix(M, k=2*np.sqrt(1./M.shape[1]), sym=False).astype(np.float)
    
    Rskew = librosa.segment.structure_feature(R, pad=True)
    Rskew = np.roll(Rskew, M.shape[1], axis=0)
    
    
    Rfilt = scipy.signal.medfilt2d(Rskew, kernel_size=(1, 7))
    #Rfilt = Rfilt[Rfilt.sum(axis=1) > 0, :]
    
    Rlatent = compress_data(Rfilt, 8)
    #Rlatent = compress_data(Rfilt, R.shape[0])
    
    figure(figsize=(12,4))
    subplot(131)
    myimshow(R), title('Self-similarity')
    xlabel('Beat'), ylabel('Beat')
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    yticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(132)
    myimshow(Rskew), title('Skewed self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(133)
    myimshow(Rfilt), title('Filtered self-sim.')
    xlabel('Beat'), ylabel('Lag')
    yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    tight_layout()
    
    # Do the SVD
    U, sigma, Vh = scipy.linalg.svd(Rfilt)
    
    D_little = 32
    
    figure(figsize=(12,4))
    subplot(131)
    myimshow(U[:,:D_little], cmap='PRGn'), title('U')
    xlabel('Factor'), ylabel('Lag')
    #yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    #xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    
    subplot(132)
    plot(sigma / sigma[0]), axis('tight'), title('Normalized spectrum $\sigma/\sigma_1$')
    vlines([D_little], 0, 1)
    
    subplot(133)
    myimshow(Vh[:D_little], cmap='PRGn'), title('V\'')
    xlabel('Beat'), ylabel('Factor')
    #yticks(range(0, Rskew.shape[0] + 1, Rskew.shape[0] / 6), range(-M.shape[1]+1, M.shape[1], Rskew.shape[0] / 6))
    #xticks(range(0, M.shape[1] + 1, M.shape[1] / 6))
    tight_layout()
    # Reconstruct
    S_hat = np.zeros(U.shape[1])
    S_hat[:D_little] = sigma[:D_little]
    
    R_reconst = U.dot(np.diag(S_hat))
    R_reconst = R_reconst[:, :Vh.shape[0]].dot(Vh)
    
    figure(figsize=(12,6))
    subplot(121)
    myimshow(Rfilt), title('Original')
    subplot(122)
    myimshow(R_reconst), title('Reconstruction (d=%2d)' % D_little)
    tight_layout()

# %%
rep_feature_svd(M)#[:,40:137])
